# %% [markdown]
# # Gobierno y Toma de Decisiones
#
# ## Prof. José Manuel Magallanes
#
# ________
#
# Hemos organizado estos datos sobre denuncias del [DATACRIM](https://datacrim.inei.gob.pe/panel/mapa)

# %%
link='https://github.com/PoliticayGobiernoPUCP/Gob_TomaDeDecisiones/raw/refs/heads/master/distritos.gpkg'

import geopandas as gpd
crimen=gpd.read_file(link, layer='crimen')
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_AppDefinedError: database disk image is malformed
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[5], line 4
#       1 link='https://github.com/PoliticayGobiernoPUCP/Gob_TomaDeDecisiones/raw/refs/heads/master/distritos.gpkg'
#       3 import geopandas as gpd
# ----> 4 crimen=gpd.read_file(link, layer='crimen')
#
# File ~/opt/anaconda3/envs/Gov_Analytics_3_11/lib/python3.11/site-packages/geopandas/io/file.py:289, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     286     else:
#     287         path_or_bytes = filename
# --> 289     return _read_file_fiona(
# ...

# %%
crimen.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DEPARTAMEN           1393 non-null   object
#  1   PROVINCIA            1393 non-null   object
#  2   DISTRITO             1393 non-null   object
#  3   INSTITUCIO           1393 non-null   object
#  4   merger               1393 non-null   object
#  5   cod                  1393 non-null   object
#  6   2015                 1393 non-null   float64
#  7   2024                 1393 non-null   float64
#  8   tasa2024_2015        1393 non-null   float64
#  9   tasa_grupo           1393 non-null   int64
#  10  outlierTasa          1393 non-null   bool
#  11  Tasa_quadrant        1393 non-null   int64
#  12  Tasa_quadrant_names  1393 non-null   object
#  13  geometry             1393 non-null   geometry
# dtypes: bool(1), float64(3), geometry(1), int64(2), object(7)
# ...

# %% [markdown]
# - 0   DEPARTAMEN: Nombre del departamento
# - 1   PROVINCIA: Nombre de la provincia
# - 2   DISTRITO: Nombre del distrito
# - 3   INSTITUCIO: que prepara el mapa
# - 4   merger: columna para añadir otras tablas
# - 5   cod: Ubigeo
# - 6   2015: Cantidad de Denuncias en el 2015
# - 7   2024: Cantidad de Denuncias en el 2024
# - 8   tasa2024_2015: division 2024/2015
# - 9   tasa_grupo: si disminuye, está igual o empeora (crimen 2015 al 2014)
# - 10  outlierTasa: valores atípicos
# - 11  Tasa_quadrant: quadrante (spot o atipicos)
# - 12  Tasa_quadrant_names: nombre del quadrante (spot o atipicos)

# %% [markdown]
# ## OBJETIVO: donde focalizar la acción, para luego escalarla.
